# %%
#import lib
import pandas as pd
from sklearn import tree
from sklearn.model_selection import train_test_split


from matplotlib import pyplot as plt

# %%
df = pd.read_csv('heart.csv')
df.head(10)
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
# 5   57    1   0     140   192    0        1       148     0      0.4    1
# 6   56    0   1     140   294    0        0       153     0      1.3    1
# 7   44    1   1     120   263    0        1       173     0      0.0    2
# 8   52    1   2     172   199    1        1       162     0      0.5    2
# 9   57    1   2     150   168    0        1       174     0      1.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1
# 5    0      1       1
# 6    0      2       1
# 7    0      3       1
# 8    0      3       1
# 9    0      2       1

# %%
data_y = df['output']
data_x = df.drop(['output'], axis = 1)

# %%
df.head(10)
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB
#               age         sex          cp      trtbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#             thall      output
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %%
data_y = df['output']
data_x = df.drop(['output'], axis = 1)

# %%
train_x, test_x, train_y, test_y = train_test_split(data_x, data_y, test_size=0.3, random_state=50)

# %%
train_x
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 121   59    1   0     138   271    0        0       182     0      0.0    2
# 145   70    1   1     156   245    0        0       143     0      0.0    2
# 144   76    0   2     140   197    0        2       116     0      1.1    1
# 244   56    1   0     132   184    0        0       105     1      2.1    1
# 160   56    1   1     120   240    0        1       169     0      0.0    0
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 70    54    1   2     120   258    0        0       147     0      0.4    1
# 132   42    1   1     120   295    0        1       162     0      0.0    2
# 289   55    0   0     128   205    0        2       130     1      2.0    1
# 109   50    0   0     110   254    0        0       159     0      0.0    2
# 176   60    1   0     117   230    1        1       160     1      1.4    2
#
#      caa  thall
# 121    0      2
# 145    0      2
# 144    0      2
# 244    1      1
# 160    0      2
# ..   ...    ...
# 70     0      3
# 132    0      2
# 289    1      3
# 109    0      2
# 176    2      3
#
# [212 rows x 13 columns]

# %%
from sklearn import tree
TR = tree.DecisionTreeClassifier()
TR.fit(train_x, train_y)
# Out:
# DecisionTreeClassifier()

# %%
tree.plot_tree(TR)
# Out:
# [Text(0.5403645833333334, 0.9375, 'X[2] <= 0.5\ngini = 0.498\nsamples = 212\nvalue = [99, 113]'),
#  Text(0.2916666666666667, 0.8125, 'X[11] <= 0.5\ngini = 0.382\nsamples = 101\nvalue = [75, 26]'),
#  Text(0.16666666666666666, 0.6875, 'X[8] <= 0.5\ngini = 0.5\nsamples = 44\nvalue = [22, 22]'),
#  Text(0.08333333333333333, 0.5625, 'X[12] <= 2.5\ngini = 0.32\nsamples = 20\nvalue = [4, 16]'),
#  Text(0.041666666666666664, 0.4375, 'X[7] <= 96.5\ngini = 0.208\nsamples = 17\nvalue = [2, 15]'),
#  Text(0.020833333333333332, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.0625, 0.3125, 'X[4] <= 316.0\ngini = 0.117\nsamples = 16\nvalue = [1, 15]'),
#  Text(0.041666666666666664, 0.1875, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.08333333333333333, 0.1875, 'X[10] <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.0625, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.10416666666666667, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.125, 0.4375, 'X[6] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.10416666666666667, 0.3125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.14583333333333334, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.25, 0.5625, 'X[10] <= 1.5\ngini = 0.375\nsamples = 24\nvalue = [18, 6]'),
#  Text(0.20833333333333334, 0.4375, 'X[3] <= 112.0\ngini = 0.198\nsamples = 18\nvalue = [16, 2]'),
#  Text(0.1875, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.22916666666666666, 0.3125, 'X[7] <= 149.0\ngini = 0.111\nsamples = 17\nvalue = [16, 1]'),
#  Text(0.20833333333333334, 0.1875, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.25, 0.1875, 'X[0] <= 48.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.22916666666666666, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2708333333333333, 0.0625, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.2916666666666667, 0.4375, 'X[0] <= 52.0\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.2708333333333333, 0.3125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3125, 0.3125, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.4166666666666667, 0.6875, 'X[1] <= 0.5\ngini = 0.131\nsamples = 57\nvalue = [53, 4]'),
#  Text(0.3541666666666667, 0.5625, 'X[9] <= 1.05\ngini = 0.444\nsamples = 9\nvalue = [6, 3]'),
#  Text(0.3333333333333333, 0.4375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.375, 0.4375, 'X[0] <= 63.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.3541666666666667, 0.3125, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.3958333333333333, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4791666666666667, 0.5625, 'X[7] <= 106.5\ngini = 0.041\nsamples = 48\nvalue = [47, 1]'),
#  Text(0.4583333333333333, 0.4375, 'X[9] <= 1.0\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.4375, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4791666666666667, 0.3125, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.5, 0.4375, 'gini = 0.0\nsamples = 42\nvalue = [42, 0]'),
#  Text(0.7890625, 0.8125, 'X[12] <= 2.5\ngini = 0.339\nsamples = 111\nvalue = [24, 87]'),
#  Text(0.6822916666666666, 0.6875, 'X[11] <= 1.5\ngini = 0.193\nsamples = 83\nvalue = [9, 74]'),
#  Text(0.59375, 0.5625, 'X[11] <= 0.5\ngini = 0.104\nsamples = 73\nvalue = [4, 69]'),
#  Text(0.5416666666666666, 0.4375, 'X[3] <= 109.0\ngini = 0.033\nsamples = 59\nvalue = [1, 58]'),
#  Text(0.5208333333333334, 0.3125, 'X[7] <= 159.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.5, 0.1875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5416666666666666, 0.1875, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.5625, 0.3125, 'gini = 0.0\nsamples = 55\nvalue = [0, 55]'),
#  Text(0.6458333333333334, 0.4375, 'X[7] <= 163.5\ngini = 0.337\nsamples = 14\nvalue = [3, 11]'),
#  Text(0.6041666666666666, 0.3125, 'X[12] <= 1.5\ngini = 0.165\nsamples = 11\nvalue = [1, 10]'),
#  Text(0.5833333333333334, 0.1875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.625, 0.1875, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.6875, 0.3125, 'X[6] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.6666666666666666, 0.1875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7083333333333334, 0.1875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7708333333333334, 0.5625, 'X[7] <= 165.5\ngini = 0.5\nsamples = 10\nvalue = [5, 5]'),
#  Text(0.75, 0.4375, 'X[0] <= 67.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.7291666666666666, 0.3125, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.7708333333333334, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7916666666666666, 0.4375, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.8958333333333334, 0.6875, 'X[9] <= 1.1\ngini = 0.497\nsamples = 28\nvalue = [15, 13]'),
#  Text(0.8541666666666666, 0.5625, 'X[4] <= 280.0\ngini = 0.408\nsamples = 14\nvalue = [4, 10]'),
#  Text(0.8333333333333334, 0.4375, 'X[10] <= 0.5\ngini = 0.278\nsamples = 12\nvalue = [2, 10]'),
#  Text(0.8125, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8541666666666666, 0.3125, 'X[7] <= 150.5\ngini = 0.165\nsamples = 11\nvalue = [1, 10]'),
#  Text(0.8333333333333334, 0.1875, 'X[3] <= 126.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.8125, 0.0625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8541666666666666, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.875, 0.1875, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.875, 0.4375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9375, 0.5625, 'X[10] <= 0.5\ngini = 0.337\nsamples = 14\nvalue = [11, 3]'),
#  Text(0.9166666666666666, 0.4375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9583333333333334, 0.4375, 'X[4] <= 242.5\ngini = 0.26\nsamples = 13\nvalue = [11, 2]'),
#  Text(0.9375, 0.3125, 'X[9] <= 1.95\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.9166666666666666, 0.1875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9583333333333334, 0.1875, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.9791666666666666, 0.3125, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]')]
